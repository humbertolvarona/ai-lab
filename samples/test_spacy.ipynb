# %%
# !pip download https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl -d data/
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 35.8 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached murmurhash-1.0.12-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# ...
#   Using cached cymem-2.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# ...
#   Using cached preshed-3.0.9-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached srsly-2.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...

# %%
# !unzip data/en_core_web_sm-3.7.1-py3-none-any.whl -d data/en_core_web_sm
# Out:
# Archive:  data/en_core_web_sm-3.7.1-py3-none-any.whl
#   inflating: data/en_core_web_sm/en_core_web_sm/__init__.py
#   inflating: data/en_core_web_sm/en_core_web_sm/meta.json
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/LICENSE
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/LICENSES_SOURCES
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/README.md
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/accuracy.json
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/config.cfg
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/meta.json
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/tokenizer
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/attribute_ruler/patterns
#   inflating: data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1/lemmatizer/lookups/lookups.bin
# ...

# %%
import spacy

# %%
nlp = spacy.load("data/en_core_web_sm/en_core_web_sm/en_core_web_sm-3.7.1")

# %%
doc = nlp("Barack Obama was the 44th President of the United States.")

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Barack Obama PERSON
# 44th ORDINAL
# the United States GPE
